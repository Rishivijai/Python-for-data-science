# %%
class Species:
    def s_species(self):
        print('Each species within the genus is named after its features and characteristics. The names of animals are based in Latin and consist of two words. The first word in the name of an animal will be the genus, and the second name indicates the specific species. This method of organizing scientific names of animal species was developed by Carl Linnaeus in the 1700’s. As an example, a dolphin species name is Delphinus Delphis. A red fox is Vulpes vulpes.')

class Genus(Species):
    def s_genus(self):
        print('A genus is a taxonomic rank used in the biological classification of living organisms. It is one step above species and one below family in the hierarchical classification system. A genus consists of one or more species that are closely related. The genus name is always written with an initial capital letter and is often used as the first part of the scientific name for an organism.')
    def panthera(self):
        print('This genus includes big cats such as lions (Panthera leo), tigers (Panthera tigris), leopards (Panthera pardus), and jaguars (Panthera onca).')
    def canis(self):
        print('This genus includes domestic dogs (Canis lupus familiaris) and their wild relatives such as gray wolves (Canis lupus) and coyotes (Canis latrans).')
    def felis(self):
        print('This genus includes domestic cats (Felis catus) and smaller wildcats such as the domestic cats wild ancestor, the African wildcat (Felis silvestris lybica).')
    def elephas(self):
        print('This genus includes elephants, with the Asian elephant (Elephas maximus) and the African elephant (Loxodonta africana).')
    def equus(self):
        print('This genus includes horses (Equus ferus caballus), donkeys (Equus africanus asinus), and zebras (various species in the genus Equus).')
    def mus(self):
        print('This genus includes house mice (Mus musculus) and various other mouse species.')

class Family(Genus):
    def s_family(self):
        print("In every order, there are different animal families which are defined by groups that have very similar features. Animal families are basically sub-divided into two main groups–vertebrates and invertebrates.")
    def vertibrates(self):
        print('Vertebrates are animals that possess a backbone or spinal column, which is made up of vertebrae. The classification of vertebrates is based on several characteristics, including the presence or absence of jaws, limbs, and the type of covering (scales, feathers, fur, etc.). ')
    def fish(self):
        print('1. Class Agnatha (Jawless Fish): Examples include lampreys and hagfish. They lack jaws and have a cartilaginous skeleton. \n2. Class Chondrichthyes (Cartilaginous Fish): Includes sharks, rays, and skates. They have skeletons made of cartilage.')
    def amphibians(self):
        print('Examples include frogs, toads, salamanders, and newts. Amphibians typically undergo a metamorphic process, starting their lives in water and transitioning to land.')
    def reptiles(self):
        print('Examples include snakes, lizards, turtles, crocodiles, and dinosaurs (extinct). Reptiles have scales, breathe air, and lay eggs with shells.')
    def birds(self):
        print('Examples include sparrows, eagles, penguins, and ostriches. Birds are characterized by feathers, beaks, and laying eggs. They are endothermic (warm-blooded).')
    def mammals(self):
        print('Includes a diverse group of animals such as humans, dogs, cats, whales, and bats. Mammals are characterized by having mammary glands, hair or fur, and typically giving birth to live young. They are also endothermic.-')
    
    def invertibrates(self):
        print('Invertebrates are animals that do not have a backbone or spinal column. The classification of invertebrates is extensive and diverse, as it includes a vast array of animals from different phyla.')
    def porifera(self):
        print('Simple aquatic animals with porous bodies. They lack true tissues and organs.')
    def cnidaria(self):
        print('Includes jellyfish, corals, and sea anemones. These animals have specialized cells called cnidocytes that release venom to capture prey.')
    def Platyhelminthes(self):
        print('Flat, often parasitic worms. Planarians are an example of free-living flatworms, while tapeworms are parasitic flatworms.')
    def nematoda(self):
        print('Unsegmented worms with a cylindrical body. They are found in various environments, including soil and aquatic habitats.')
    def mollusca(self):
        print('Includes snails, clams, octopuses, and squids. Mollusks typically have a soft body, a muscular foot, and a mantle that may secrete a protective shell.')
    def annelida(self):
        print('Segmented worms with a true body cavity. Earthworms and leeches are examples of annelids.')
    def arthropoda(self):
        print('The largest phylum, including insects, arachnids (spiders, scorpions), crustaceans (crabs, lobsters), and myriapods (centipedes, millipedes). Arthropods have an exoskeleton and jointed appendages.')
    def Echinodermata(self):
        print('Includes starfish, sea urchins, and sea cucumbers. Echinoderms often have a spiny or calcareous endoskeleton.')
    def Ctenophora(self):
        print('Gelatinous, marine animals that move through the water using cilia. They have a distinct biradial symmetry.')
    def Rotifera(self):
        print('Microscopic, multicellular animals with a wheel-like structure of cilia at their anterior end.')
    def Tardigrada(self):
        print('Microscopic, water-dwelling animals known for their ability to survive extreme conditions.')
    def Hemichordata(self):
        print('Marine organisms with characteristics of both invertebrates and vertebrates. The group includes acorn worms.')
    

class Order(Family):
    def s_order(self):
        print('Each class is divided into small groups again, known as orders. There is no universally accepted breakdown for the class Mammalia.')
    def Artiodactyla(self):
        print('Examples include moose, camels, and giraffes')
    def Carnivora(self):
        print('Animals that specialize in mostly eating meat, but also contain some omnivores and herbivores. Characterized as having nonretractable claws and long snouts. Examples include bears.')
    def Rodentia(self):
        print('Examples include beavers, mice, and squirrels')
    def Chiropptera(self):
        print('The only mammals that can fly. Examples include free-tailed and vampire bats')
    def Cetacea(self):
        print('Examples include killer whales, dolphins, and hump-backed whales')
    def Primates(self):
        print('Includes prehensile hands and feet, commonly with opposable thumbs. Examples include gorillas, chimpanzees, and humans.')

class Class(Order):
    def s_class(self):
        print('In the biological classification of living organisms, a class is a taxonomic rank below the phylum and above the order. Classes group together related orders based on shared characteristics. Animals within the same class share more specific features than those in the same phylum but less specific features than those in the same order. ')
    def Agnatha(self):
        print('Agnatha (jaw-less fish) –  Primitive jawless fish including lampreys, hagfishes, and extinct groups.')
    def Chrondrichtyes(self):
        print('Composed of fish with skeletons composed of cartilage. Includes two subclasses: Elasmobranchii (rays, skates, sawfish, and sharks); Holocephali (chimaeras–ghost sharks).')
    def Osteichthyes(self):
        print('Includes saltwater and freshwater fish with bony skeletons like eels, anglerfish, clown fish, swordfish, and catfish, carp, trout, and salmonids.')
    def Amphibia(self):
        print('Four-limbed, ectothermic vertebrates, including frogs, toads, salamanders, and newts.')
    def Reptilia(self):
        print('Vertebrates with dry skin and scales such as snakes, turtles, lizards, and crocodilians.')
    def Aves(self):
        print('Warm-blooded, egg-laying animals characterized by two wings, two legs, and feathers.')
    def Mammalia(self):
        print('Warm-blooded four-legged (or two-armed, two-legged) animals that breathe with lungs and birth live young.')

class Phylum(Class):
    def s_phylum(self):
        print('In biological taxonomy, a phylum is a rank below the kingdom and above the class. It is a way of categorizing and organizing living organisms based on certain key characteristics. The animal kingdom is broadly divided into several major phyla.')
    def porifera(self):
        print('Simple aquatic animals with porous bodies. They lack true tissues and organs.')
    def cnidaria(self):
        print('Includes jellyfish, corals, and sea anemones. These animals have specialized cells called cnidocytes that release venom to capture prey.')
    def Platyhelminthes(self):
        print('Flat, often parasitic worms. Planarians are an example of free-living flatworms, while tapeworms are parasitic flatworms.')
    def Nematoda(self):
        print('Unsegmented worms with a cylindrical body. They are found in various environments, including soil and aquatic habitats.')
    def Mollusca(self):
        print('Includes snails, clams, octopuses, and squids. Mollusks typically have a soft body, a muscular foot, and a mantle that may secrete a protective shell.')
    def Annelida(self):
        print('Segmented worms with a true body cavity. Earthworms and leeches are examples of annelids.')
    def Arthropoda(self):
        print('The largest phylum, including insects, arachnids (spiders, scorpions), crustaceans (crabs, lobsters), and myriapods (centipedes, millipedes). Arthropods have an exoskeleton and jointed appendages.')
    def Echinodermata(self):
        print('Includes starfish, sea urchins, and sea cucumbers. Echinoderms often have a spiny or calcareous endoskeleton.')
    def Chordata(self):
        print('Includes animals with a notochord (a flexible rod-like structure) at some stage of their development. Chordates are divided into three subphyla: Urochordata (tunicates), Cephalochordata (lancelets), and Vertebrata (vertebrates).')

class Kingdom(Phylum):
    def s_kingdom(self):
        print('The animal kingdom, also known as Animalia, is one of the major biological kingdoms and encompasses a vast diversity of multicellular organisms. Animals are characterized by their ability to move, typically exhibit a complex range of behaviors, and are generally heterotrophic (meaning they obtain their nutrients by consuming other organisms).')
    def Animal(self):
        print('A kingdom of complex multi-celled organisms that do not produce their own food. This kingdom contains all living and extinct animals. Examples include elephants, whales, and humans.')
    def Plants(self):
        print('Complex and multi-cellular autotrophic organisms, meaning they produce their own food through photosynthesis. Examples include trees, flowers, and grass.')
    def Fungi(self):
        print('Multi-celled organisms that do not produce their own food, unlike plants. Examples include molds, mushrooms, and yeast.')
    def Eubacteria(self):
        print('Single-celled organisms found in everything from yogurt to your intestines. This kingdom contains all bacteria in the world not considered archaebacteria.')
    def Archaebacteria(self):
        print('The oldest known living organisms. Single-celled and found in hostile and extremely hot areas like thermal vents or hot springs')

class Domain(Kingdom):
    def s_domain(self):
        print('The domain is the highest taxonomic rank in biological classification. There are three main domains: Bacteria, Archaea, and Eukarya. Animals belong to the domain Eukarya, which is characterized by the presence of cells with a true nucleus enclosed in a membrane.')
    def Bacteria(self):
        print('Bacteria are unicellular microorganisms that lack a nucleus and other membrane-bound organelles. They are found in various environments and play crucial roles in processes such as nutrient cycling.')
    def Archaea(self):
        print('Archaea are also unicellular microorganisms, similar to bacteria, but they differ in fundamental ways, particularly in their genetic makeup and certain biochemical processes. Some archaea are extremophiles, thriving in extreme environments such as hot springs and deep-sea vents.')
    def Eukarya(self):
        print('Eukarya is the domain that includes all eukaryotic organisms, which have cells with a true nucleus and membrane-bound organelles. This domain encompasses a wide range of life forms, including plants, fungi, protists, and animals.')

class Animal_Classification(Domain):
    
    animal_species = {
    "lion": "Panthera leo",
    "elephant": "Loxodonta africana",
    "giraffe": "Giraffa camelopardalis",
    "zebra": "Equus zebra",
    "tiger": "Panthera tigris",
    "kangaroo": "Macropus",
    "monkey": "Primate",
    "koala": "Phascolarctos cinereus",
    "penguin": "Spheniscidae",
    "snake": "Serpentes",
    "dog": "Canis lupus familiaris",
    "cat": "Felis catus",
    "horse": "Equus ferus caballus",
    "cow": "Bos taurus",
    "sheep": "Ovis aries",
    "goat": "Capra aegagrus hircus",
    "rabbit": "Oryctolagus cuniculus",
    "deer": "Cervidae",
    "fox": "Vulpes vulpes",
    "bear": "Ursidae",
    "panda": "Ailuropoda melanoleuca",
    "elephant_seal": "Mirounga",
    "whale": "Cetacea",
    "dolphin": "Delphinidae",
    "shark": "Selachimorpha",
    "octopus": "Octopoda",
    "sloth": "Folivora",
    "pangolin": "Pholidota",
    "hippopotamus": "Hippopotamus amphibius",
    "rhinoceros": "Rhinocerotidae",
    "camel": "Camelidae",
    "polar_bear": "Ursus maritimus",
    "cheetah": "Acinonyx jubatus",
    "wolf": "Canis lupus",
    "bat": "Chiroptera",
    "pigeon": "Columba livia",
    "parrot": "Psittaciformes",
    "frog": "Anura",
    "turtle": "Testudines",
    "crocodile": "Crocodylidae",
    "komodo_dragon": "Varanus komodoensis",
    "gorilla": "Gorilla",
    "chimpanzee": "Pan troglodytes",
    "lemur": "Lemuriformes",
    "meerkat": "Suricata suricatta",
    "peacock": "Pavo",
    "ostrich": "Struthio camelus",
    "platypus": "Ornithorhynchus anatinus",
    "hedgehog": "Erinaceinae",
    "beaver": "Castor",
    "armadillo": "Cingulata",
    "raccoon": "Procyon lotor",
    "kookaburra": "Dacelo",
    "anteater": "Myrmecophagidae",
    "elephant_shrew": "Macroscelididae",
    "lemming": "Lemmus",
    "quokka": "Setonix brachyurus",
    "gazelle": "Antilopinae",
    "lemur": "Lemur",
    "toucan": "Ramphastidae",
    "spider": "Arachnida",
    "snail": "Gastropoda",
    "jellyfish": "Cnidaria",
    "crab": "Decapoda",
    "koala": "Phascolarctos cinereus",
    "anteater": "Myrmecophagidae",
    "lemur": "Lemur",
    "toucan": "Ramphastidae",
    "spider": "Arachnida",
    "snail": "Gastropoda",
    "jellyfish": "Cnidaria",
    "crab": "Decapoda",
    "starfish": "Asteroidea",
    "seahorse": "Hippocampus",
    "butterfly": "Lepidoptera",
    "dragonfly": "Odonata",
    "bee": "Anthophila",
    "mosquito": "Culicidae",
    "fly": "Diptera",
    "ladybug": "Coccinellidae",
    "caterpillar": "Lepidoptera",
    "lizard": "Squamata",
    "gecko": "Gekkota",
    "iguana": "Iguanidae",
    "chameleon": "Chamaeleonidae",
    "tarantula": "Theraphosidae",
    "scorpion": "Scorpiones",
    "millipede": "Diplopoda",
    "centipede": "Chilopoda",
    "slug": "Gastropoda",
    "worm": "Annelida",
    "snail": "Gastropoda",
    "fish": "Pisces",
    "goldfish": "Carassius auratus",
    "clownfish": "Amphiprioninae",
    "shrimp": "Decapoda",
    "lobster": "Nephropidae",
    "crab": "Decapoda",
    "octopus": "Octopoda",
    "starfish": "Asteroidea",
    "seahorse": "Hippocampus",
    "jellyfish": "Cnidaria",
    "coral": "Anthozoa",
    "whale_shark": "Rhincodon typus",
    "hammerhead_shark": "Sphyrnidae",
    "ray": "Batoidea",
    "dolphin": "Delphinidae",
    "sea_turtle": "Cheloniidae",
    "penguin": "Spheniscidae",
    "seagull": "Laridae",
    "pelican": "Pelecanidae",
    "albatross": "Diomedeidae",
    "ostrich": "Struthio camelus",
    "emu": "Dromaius novaehollandiae",
    "kiwi": "Apteryx",
    "puffin": "Fratercula",
    "platypus": "Ornithorhynchus anatinus",
    "beaver": "Castor",
    "otter": "Lutrinae",
    "seal": "Pinnipedia",
    "polar_bear": "Ursus maritimus",
    "armadillo": "Cingulata",
    "sloth": "Folivora",
    "anteater": "Myrmecophagidae",
    "hedgehog": "Er"}
    
    plants_species = {
    "Rose": "Rosa",
    "Oak": "Quercus",
    "Tulip": "Tulipa",
    "Sunflower": "Helianthus annuus",
    "Cactus": "Cactaceae",
    "Maple": "Acer",
    "Lily": "Lilium",
    "Daisy": "Bellis perennis",
    "Bamboo": "Bambusoideae",
    "Fern": "Polypodiopsida",
    "Apple tree": "Malus domestica",
    "Lavender": "Lavandula",
    "Pineapple": "Ananas comosus",
    "Cherry blossom": "Prunus serrulata",
    "Daffodil": "Narcissus",
    "Bonsai": "Various species",
    "Carnation": "Dianthus caryophyllus",
    "Dandelion": "Taraxacum",
    "Bamboo palm": "Chamaedorea seifrizii",
    "Cypress": "Cupressus",
    "Zinnia": "Zinnia elegans",
    "Aloe vera": "Aloe barbadensis miller",
    "Moss": "Bryophyta",
    "Orchid": "Orchidaceae",
    "Palm tree": "Arecaceae",
    "Geranium": "Pelargonium",
    "Cactus": "Cactaceae",
    "Fuchsia": "Fuchsia",
    "Basil": "Ocimum basilicum",
    "Fir": "Abies",
    "Violet": "Viola",
    "Lemon tree": "Citrus limon",
    "Peony": "Paeonia",
    "Chrysanthemum": "Chrysanthemum",
    "Cedar": "Cedrus",
    "Cyclamen": "Cyclamen",
    "Hibiscus": "Hibiscus",
    "Ivy": "Hedera",
    "Azalea": "Rhododendron",
    "African violet": "Saintpaulia",
    "Birch": "Betula",
    "Tomato plant": "Solanum lycopersicum",
    "Poinsettia": "Euphorbia pulcherrima",
    "Juniper": "Juniperus",
    "Chia plant": "Salvia hispanica",
    "Columbine": "Aquilegia",
    "Boxwood": "Buxus",
    "Ginseng": "Panax",
    "Marigold": "Tagetes",
    "Magnolia": "Magnolia",
    "Grapevine": "Vitis",
    "Cotton plant": "Gossypium",
    "Begonia": "Begonia",
    "Plumeria": "Plumeria",
    "Hosta": "Hosta",
    "Mint": "Mentha",
    "Jasmine": "Jasminum",
    "Chamomile": "Matricaria chamomilla",
    "Sage": "Salvia",
    "Papyrus": "Cyperus papyrus",
    "Petunia": "Petunia",
    "Forsythia": "Forsythia",
    "Succulent": "Various species",
    "Bee balm": "Monarda",
    "Cattail": "Typha",
    "Cattleya orchid": "Cattleya",
    "Cauliflower": "Brassica oleracea",
    "Cornflower": "Centaurea cyanus",
    "Cranberry bush": "Vaccinium macrocarpon",
    "Croton": "Codiaeum variegatum",
    "Dill": "Anethum graveolens",
    "Elderberry": "Sambucus",
    "Flowering dogwood": "Cornus florida",
    "Forsythia": "Forsythia",
    "Hollyhock": "Alcea",
    "Honeysuckle": "Lonicera",
    "Hyacinth": "Hyacinthus",
    "Hydrangea": "Hydrangea",
    "Jackfruit tree": "Artocarpus heterophyllus",
    "Kale": "Brassica oleracea",
    "Lantana": "Lantana",
    "Lettuce": "Lactuca sativa",
    "Lilac": "Syringa",
    "Lobelia": "Lobelia",
    "Mango tree": "Mangifera indica",
    "Mimosa": "Mimosa pudica",
    "Nasturtium": "Tropaeolum",
    "Nectarine tree": "Prunus persica var. nucipersica",
    "Nepenthes": "Nepenthes",
    "Oregano": "Origanum vulgare",
    "Pansy": "Viola tricolor",
    "Passionflower": "Passiflora",
    "Peach tree": "Prunus persica",
    "Pear tree": "Pyrus",
    "Pecan tree": "Carya illinoinensis",
    "Pine tree": "Pinus",
    "Poinsettia": "Euphorbia pulcherrima",
    "Prickly pear cactus": "Opuntia",
    "Quince tree": "Cydonia oblonga",
    "Raspberry bush": "Rubus idaeus",
    "Red hot poker": "Kniphofia",
    "Rosemary": "Rosmarinus officinalis",
    "Saffron": "Crocus sativus",
    "Snowdrop": "Galanthus",
    "Strawberry plant": "Fragaria × ananassa",
    "Thyme": "Thymus"}
    
    animals_genus = {
    "lion": "Panthera",
    "elephant": "Loxodonta",
    "giraffe": "Giraffa",
    "zebra": "Equus",
    "tiger": "Panthera",
    "kangaroo": "Macropus",
    "monkey": "Simia",
    "koala": "Phascolarctos",
    "penguin": "Spheniscus",
    "snake": "Serpentes",
    "dog": "Canis",
    "cat": "Felis",
    "horse": "Equus",
    "cow": "Bos",
    "sheep": "Ovis",
    "goat": "Capra",
    "rabbit": "Oryctolagus",
    "deer": "Cervus",
    "fox": "Vulpes",
    "bear": "Ursus",
    "panda": "Ailuropoda",
    "elephant_seal": "Mirounga",
    "whale": "Balaenoptera",
    "dolphin": "Delphinus",
    "shark": "Selachimorpha",
    "octopus": "Octopus",
    "sloth": "Bradypus",
    "pangolin": "Manis",
    "hippopotamus": "Hippopotamus",
    "rhinoceros": "Rhinocerotidae",
    "camel": "Camelus",
    "polar_bear": "Ursus maritimus",
    "cheetah": "Acinonyx",
    "wolf": "Canis",
    "bat": "Chiroptera",
    "pigeon": "Columba",
    "parrot": "Psittacidae",
    "frog": "Rana",
    "turtle": "Testudines",
    "crocodile": "Crocodylus",
    "komodo_dragon": "Varanus",
    "gorilla": "Gorilla",
    "chimpanzee": "Pan",
    "lemur": "Lemur",
    "meerkat": "Suricata",
    "peacock": "Pavo",
    "ostrich": "Struthio",
    "platypus": "Ornithorhynchus",
    "hedgehog": "Erinaceus",
    "beaver": "Castor",
    "armadillo": "Dasypodidae",
    "raccoon": "Procyon",
    "kookaburra": "Dacelo",
    "anteater": "Myrmecophaga",
    "elephant_shrew": "Elephantulus",
    "lemming": "Lemmus",
    "quokka": "Setonix",
    "gazelle": "Gazella",
    "toucan": "Ramphastos",
    "spider": "Araneae",
    "snail": "Helix",
    "jellyfish": "Cnidaria",
    "crab": "Decapoda",
    "starfish": "Asteroidea",
    "seahorse": "Hippocampus",
    "butterfly": "Lepidoptera",
    "dragonfly": "Odonata",
    "bee": "Apis",
    "mosquito": "Culicidae",
    "fly": "Diptera",
    "ladybug": "Coccinellidae",
    "caterpillar": "Lepidoptera",
    "lizard": "Sauria",
    "gecko": "Gekkota",
    "iguana": "Iguana",
    "chameleon": "Chamaeleonidae",
    "tarantula": "Theraphosidae",
    "scorpion": "Scorpiones",
    "millipede": "Diplopoda",
    "centipede": "Chilopoda",
    "slug": "Gastropoda",
    "worm": "Annelida",
    "fish": "Pisces",
    "goldfish": "Carassius auratus",
    "clownfish": "Amphiprioninae",
    "shrimp": "Decapoda",
    "lobster": "Nephropidae",
    "coral": "Anthozoa",
    "whale_shark": "Rhincodon typus",
    "hammerhead_shark": "Sphyrnidae",
    "ray": "Batoidea",
    "sea_turtle": "Cheloniidae",
    "seagull": "Laridae",
    "pelican": "Pelecanidae",
    "albatross": "Diomedeidae",
    "emu": "Dromaius",
    "kiwi": "Apteryx",
    "puffin": "Fratercula",
    "otter": "Lutra",
    "seal": "Pinnipedia"}
    
    
    animal_families = {
    "lion": "Mammal",
    "elephant": "Mammal",
    "giraffe": "Mammal",
    "zebra": "Mammal",
    "tiger": "Mammal",
    "kangaroo": "Mammal",
    "monkey": "Mammal",
    "koala": "Mammal",
    "penguin": "Bird",
    "snake": "Reptile",
    "dog": "Mammal",
    "cat": "Mammal",
    "horse": "Mammal",
    "cow": "Mammal",
    "sheep": "Mammal",
    "goat": "Mammal",
    "rabbit": "Mammal",
    "deer": "Mammal",
    "fox": "Mammal",
    "bear": "Mammal",
    "panda": "Mammal",
    "elephant_seal": "Mammal",
    "whale": "Mammal",
    "dolphin": "Mammal",
    "shark": "Fish",
    "octopus": "Mollusk",
    "sloth": "Mammal",
    "pangolin": "Mammal",
    "hippopotamus": "Mammal",
    "rhinoceros": "Mammal",
    "camel": "Mammal",
    "polar_bear": "Mammal",
    "cheetah": "Mammal",
    "wolf": "Mammal",
    "bat": "Mammal",
    "pigeon": "Bird",
    "parrot": "Bird",
    "frog": "Amphibian",
    "turtle": "Reptile",
    "crocodile": "Reptile",
    "komodo_dragon": "Reptile",
    "gorilla": "Mammal",
    "chimpanzee": "Mammal",
    "lemur": "Mammal",
    "meerkat": "Mammal",
    "peacock": "Bird",
    "ostrich": "Bird",
    "platypus": "Mammal",
    "hedgehog": "Mammal",
    "beaver": "Mammal",
    "armadillo": "Mammal",
    "raccoon": "Mammal",
    "kookaburra": "Bird",
    "anteater": "Mammal",
    "elephant_shrew": "Mammal",
    "lemming": "Mammal",
    "quokka": "Mammal",
    "gazelle": "Mammal",
    "toucan": "Bird",
    "spider": "Arachnid",
    "snail": "Mollusk",
    "jellyfish": "Cnidarian",
    "crab": "Crustacean",
    "starfish": "Echinoderm",
    "seahorse": "Fish",
    "butterfly": "Insect",
    "dragonfly": "Insect",
    "bee": "Insect",
    "mosquito": "Insect",
    "fly": "Insect",
    "ladybug": "Insect",
    "caterpillar": "Insect",
    "lizard": "Reptile",
    "gecko": "Reptile",
    "iguana": "Reptile",
    "chameleon": "Reptile",
    "tarantula": "Arachnid",
    "scorpion": "Arachnid",
    "millipede": "Myriapod",
    "centipede": "Myriapod",
    "slug": "Mollusk",
    "worm": "Annelid",
    "fish": "Fish",
    "goldfish": "Fish",
    "clownfish": "Fish",
    "shrimp": "Crustacean",
    "lobster": "Crustacean",
    "coral": "Cnidarian",
    "whale_shark": "Fish",
    "hammerhead_shark": "Fish",
    "ray": "Fish",
    "sea_turtle": "Reptile",
    "seagull": "Bird",
    "pelican": "Bird",
    "albatross": "Bird",
    "emu": "Bird",
    "kiwi": "Bird",
    "puffin": "Bird",
    "otter": "Mammal",
    "seal": "Mammal"}
    
    animal_orders = {
    "lion": "Carnivora",
    "elephant": "Proboscidea",
    "giraffe": "Artiodactyla",
    "zebra": "Perissodactyla",
    "tiger": "Carnivora",
    "kangaroo": "Diprotodontia",
    "monkey": "Primates",
    "koala": "Diprotodontia",
    "penguin": "Sphenisciformes",
    "snake": "Squamata",
    "dog": "Carnivora",
    "cat": "Carnivora",
    "horse": "Perissodactyla",
    "cow": "Artiodactyla",
    "sheep": "Artiodactyla",
    "goat": "Artiodactyla",
    "rabbit": "Lagomorpha",
    "deer": "Artiodactyla",
    "fox": "Carnivora",
    "bear": "Carnivora",
    "panda": "Carnivora",
    "elephant_seal": "Carnivora",
    "whale": "Cetacea",
    "dolphin": "Cetacea",
    "shark": "Selachimorpha",
    "octopus": "Octopoda",
    "sloth": "Pilosa",
    "pangolin": "Pholidota",
    "hippopotamus": "Artiodactyla",
    "rhinoceros": "Perissodactyla",
    "camel": "Artiodactyla",
    "polar_bear": "Carnivora",
    "cheetah": "Carnivora",
    "wolf": "Carnivora",
    "bat": "Chiroptera",
    "pigeon": "Columbiformes",
    "parrot": "Psittaciformes",
    "frog": "Anura",
    "turtle": "Testudines",
    "crocodile": "Crocodylia",
    "komodo_dragon": "Squamata",
    "gorilla": "Primates",
    "chimpanzee": "Primates",
    "lemur": "Primates",
    "meerkat": "Carnivora",
    "peacock": "Galliformes",
    "ostrich": "Struthioniformes",
    "platypus": "Monotremata",
    "hedgehog": "Eulipotyphla",
    "beaver": "Rodentia",
    "armadillo": "Cingulata",
    "raccoon": "Carnivora",
    "kookaburra": "Coraciiformes",
    "anteater": "Pilosa",
    "elephant_shrew": "Macroscelidea",
    "lemming": "Rodentia",
    "quokka": "Diprotodontia",
    "gazelle": "Artiodactyla",
    "toucan": "Piciformes",
    "spider": "Araneae",
    "snail": "Gastropoda",
    "jellyfish": "Scyphozoa",
    "crab": "Decapoda",
    "starfish": "Asteroidea",
    "seahorse": "Syngnathiformes",
    "butterfly": "Lepidoptera",
    "dragonfly": "Odonata",
    "bee": "Hymenoptera",
    "mosquito": "Diptera",
    "fly": "Diptera",
    "ladybug": "Coleoptera",
    "caterpillar": "Lepidoptera",
    "lizard": "Squamata",
    "gecko": "Squamata",
    "iguana": "Squamata",
    "chameleon": "Squamata",
    "tarantula": "Araneae",
    "scorpion": "Scorpiones",
    "millipede": "Diplopoda",
    "centipede": "Chilopoda",
    "slug": "Gastropoda",
    "worm": "Annelida",
    "fish": "Actinopterygii",
    "goldfish": "Cypriniformes",
    "clownfish": "Perciformes",
    "shrimp": "Decapoda",
    "lobster": "Decapoda",
    "coral": "Anthozoa",
    "whale_shark": "Orectolobiformes",
    "hammerhead_shark": "Carcharhiniformes",
    "ray": "Batoidea",
    "sea_turtle": "Testudines",
    "seagull": "Charadriiformes",
    "pelican": "Pelecaniformes",
    "albatross": "Procellariiformes",
    "emu": "Palaeognathae",
    "kiwi": "Apterygiformes",
    "puffin": "Charadriiformes",
    "otter": "Carnivora",
    "seal": "Carnivora"}
    
    animal_classes = {
    "lion": "Mammalia",
    "elephant": "Mammalia",
    "giraffe": "Mammalia",
    "zebra": "Mammalia",
    "tiger": "Mammalia",
    "kangaroo": "Mammalia",
    "monkey": "Mammalia",
    "koala": "Mammalia",
    "penguin": "Aves",
    "snake": "Reptilia",
    "dog": "Mammalia",
    "cat": "Mammalia",
    "horse": "Mammalia",
    "cow": "Mammalia",
    "sheep": "Mammalia",
    "goat": "Mammalia",
    "rabbit": "Mammalia",
    "deer": "Mammalia",
    "fox": "Mammalia",
    "bear": "Mammalia",
    "panda": "Mammalia",
    "elephant_seal": "Mammalia",
    "whale": "Mammalia",
    "dolphin": "Mammalia",
    "shark": "Chondrichthyes",
    "octopus": "Cephalopoda",
    "sloth": "Mammalia",
    "pangolin": "Mammalia",
    "hippopotamus": "Mammalia",
    "rhinoceros": "Mammalia",
    "camel": "Mammalia",
    "polar_bear": "Mammalia",
    "cheetah": "Mammalia",
    "wolf": "Mammalia",
    "bat": "Chiroptera",
    "pigeon": "Aves",
    "parrot": "Aves",
    "frog": "Amphibia",
    "turtle": "Reptilia",
    "crocodile": "Reptilia",
    "komodo_dragon": "Reptilia",
    "gorilla": "Mammalia",
    "chimpanzee": "Mammalia",
    "lemur": "Mammalia",
    "meerkat": "Mammalia",
    "peacock": "Aves",
    "ostrich": "Aves",
    "platypus": "Mammalia",
    "hedgehog": "Mammalia",
    "beaver": "Mammalia",
    "armadillo": "Mammalia",
    "raccoon": "Mammalia",
    "kookaburra": "Aves",
    "anteater": "Mammalia",
    "elephant_shrew": "Mammalia",
    "lemming": "Mammalia",
    "quokka": "Mammalia",
    "gazelle": "Mammalia",
    "toucan": "Aves",
    "spider": "Arachnida",
    "snail": "Gastropoda",
    "jellyfish": "Cnidaria",
    "crab": "Malacostraca",
    "starfish": "Asteroidea",
    "seahorse": "Actinopterygii",
    "butterfly": "Lepidoptera",
    "dragonfly": "Odonata",
    "bee": "Hymenoptera",
    "mosquito": "Diptera",
    "fly": "Diptera",
    "ladybug": "Coleoptera",
    "caterpillar": "Lepidoptera",
    "lizard": "Reptilia",
    "gecko": "Reptilia",
    "iguana": "Reptilia",
    "chameleon": "Reptilia",
    "tarantula": "Arachnida",
    "scorpion": "Arachnida",
    "millipede": "Diplopoda",
    "centipede": "Chilopoda",
    "slug": "Gastropoda",
    "worm": "Annelida",
    "fish": "Actinopterygii",
    "goldfish": "Cypriniformes",
    "clownfish": "Perciformes",
    "shrimp": "Decapoda",
    "lobster": "Decapoda",
    "coral": "Anthozoa",
    "whale_shark": "Orectolobiformes",
    "hammerhead_shark": "Carcharhiniformes",
    "ray": "Batoidea",
    "sea_turtle": "Testudines",
    "seagull": "Charadriiformes",
    "pelican": "Pelecaniformes",
    "albatross": "Procellariiformes",
    "emu": "Palaeognathae",
    "kiwi": "Apterygiformes",
    "puffin": "Charadriiformes",
    "otter": "Mammalia",
    "seal": "Mammalia"}
    
    animal_phyla = {
    "lion": "Chordata",
    "elephant": "Chordata",
    "giraffe": "Chordata",
    "zebra": "Chordata",
    "tiger": "Chordata",
    "kangaroo": "Chordata",
    "monkey": "Chordata",
    "koala": "Chordata",
    "penguin": "Chordata",
    "snake": "Chordata",
    "dog": "Chordata",
    "cat": "Chordata",
    "horse": "Chordata",
    "cow": "Chordata",
    "sheep": "Chordata",
    "goat": "Chordata",
    "rabbit": "Chordata",
    "deer": "Chordata",
    "fox": "Chordata",
    "bear": "Chordata",
    "panda": "Chordata",
    "elephant_seal": "Chordata",
    "whale": "Chordata",
    "dolphin": "Chordata",
    "shark": "Chordata",
    "octopus": "Mollusca",
    "sloth": "Chordata",
    "pangolin": "Chordata",
    "hippopotamus": "Chordata",
    "rhinoceros": "Chordata",
    "camel": "Chordata",
    "polar_bear": "Chordata",
    "cheetah": "Chordata",
    "wolf": "Chordata",
    "bat": "Chordata",
    "pigeon": "Chordata",
    "parrot": "Chordata",
    "frog": "Chordata",
    "turtle": "Chordata",
    "crocodile": "Chordata",
    "komodo_dragon": "Chordata",
    "gorilla": "Chordata",
    "chimpanzee": "Chordata",
    "lemur": "Chordata",
    "meerkat": "Chordata",
    "peacock": "Chordata",
    "ostrich": "Chordata",
    "platypus": "Chordata",
    "hedgehog": "Chordata",
    "beaver": "Chordata",
    "armadillo": "Chordata",
    "raccoon": "Chordata",
    "kookaburra": "Chordata",
    "anteater": "Chordata",
    "elephant_shrew": "Chordata",
    "lemming": "Chordata",
    "quokka": "Chordata",
    "gazelle": "Chordata",
    "toucan": "Chordata",
    "spider": "Arthropoda",
    "snail": "Mollusca",
    "jellyfish": "Cnidaria",
    "crab": "Arthropoda",
    "starfish": "Echinodermata",
    "seahorse": "Chordata",
    "butterfly": "Arthropoda",
    "dragonfly": "Arthropoda",
    "bee": "Arthropoda",
    "mosquito": "Arthropoda",
    "fly": "Arthropoda",
    "ladybug": "Arthropoda",
    "caterpillar": "Arthropoda",
    "lizard": "Chordata",
    "gecko": "Chordata",
    "iguana": "Chordata",
    "chameleon": "Chordata",
    "tarantula": "Arthropoda",
    "scorpion": "Arthropoda",
    "millipede": "Arthropoda",
    "centipede": "Arthropoda",
    "slug": "Mollusca",
    "worm": "Annelida",
    "fish": "Chordata",
    "goldfish": "Chordata",
    "clownfish": "Chordata",
    "shrimp": "Arthropoda",
    "lobster": "Arthropoda",
    "coral": "Cnidaria",
    "whale_shark": "Chordata",
    "hammerhead_shark": "Chordata",
    "ray": "Chordata",
    "sea_turtle": "Chordata",
    "seagull": "Chordata",
    "pelican": "Chordata",
    "albatross": "Chordata",
    "emu": "Chordata",
    "kiwi": "Chordata",
    "puffin": "Chordata",
    "otter": "Chordata",
    "seal": "Chordata"}
    
    animal_kingdoms = {
    "lion": "Animalia",
    "elephant": "Animalia",
    "giraffe": "Animalia",
    "zebra": "Animalia",
    "tiger": "Animalia",
    "kangaroo": "Animalia",
    "monkey": "Animalia",
    "koala": "Animalia",
    "penguin": "Animalia",
    "snake": "Animalia",
    "dog": "Animalia",
    "cat": "Animalia",
    "horse": "Animalia",
    "cow": "Animalia",
    "sheep": "Animalia",
    "goat": "Animalia",
    "rabbit": "Animalia",
    "deer": "Animalia",
    "fox": "Animalia",
    "bear": "Animalia",
    "panda": "Animalia",
    "elephant_seal": "Animalia",
    "whale": "Animalia",
    "dolphin": "Animalia",
    "shark": "Animalia",
    "octopus": "Animalia",
    "sloth": "Animalia",
    "pangolin": "Animalia",
    "hippopotamus": "Animalia",
    "rhinoceros": "Animalia",
    "camel": "Animalia",
    "polar_bear": "Animalia",
    "cheetah": "Animalia",
    "wolf": "Animalia",
    "bat": "Animalia",
    "pigeon": "Animalia",
    "parrot": "Animalia",
    "frog": "Animalia",
    "turtle": "Animalia",
    "crocodile": "Animalia",
    "komodo_dragon": "Animalia",
    "gorilla": "Animalia",
    "chimpanzee": "Animalia",
    "lemur": "Animalia",
    "meerkat": "Animalia",
    "peacock": "Animalia",
    "ostrich": "Animalia",
    "platypus": "Animalia",
    "hedgehog": "Animalia",
    "beaver": "Animalia",
    "armadillo": "Animalia",
    "raccoon": "Animalia",
    "kookaburra": "Animalia",
    "anteater": "Animalia",
    "elephant_shrew": "Animalia",
    "lemming": "Animalia",
    "quokka": "Animalia",
    "gazelle": "Animalia",
    "toucan": "Animalia",
    "spider": "Animalia",
    "snail": "Animalia",
    "jellyfish": "Animalia",
    "crab": "Animalia",
    "starfish": "Animalia",
    "seahorse": "Animalia",
    "butterfly": "Animalia",
    "dragonfly": "Animalia",
    "bee": "Animalia",
    "mosquito": "Animalia",
    "fly": "Animalia",
    "ladybug": "Animalia",
    "caterpillar": "Animalia",
    "lizard": "Animalia",
    "gecko": "Animalia",
    "iguana": "Animalia",
    "chameleon": "Animalia",
    "tarantula": "Animalia",
    "scorpion": "Animalia",
    "millipede": "Animalia",
    "centipede": "Animalia",
    "slug": "Animalia",
    "worm": "Animalia",
    "fish": "Animalia",
    "goldfish": "Animalia",
    "clownfish": "Animalia",
    "shrimp": "Animalia",
    "lobster": "Animalia",
    "coral": "Animalia",
    "whale_shark": "Animalia",
    "hammerhead_shark": "Animalia",
    "ray": "Animalia",
    "sea_turtle": "Animalia",
    "seagull": "Animalia",
    "pelican": "Animalia",
    "albatross": "Animalia",
    "emu": "Animalia",
    "kiwi": "Animalia",
    "puffin": "Animalia",
    "otter": "Animalia",
    "seal": "Animalia"}
    
    animal_domains = {
    "lion": "Eukarya",
    "elephant": "Eukarya",
    "giraffe": "Eukarya",
    "zebra": "Eukarya",
    "tiger": "Eukarya",
    "kangaroo": "Eukarya",
    "monkey": "Eukarya",
    "koala": "Eukarya",
    "penguin": "Eukarya",
    "snake": "Eukarya",
    "dog": "Eukarya",
    "cat": "Eukarya",
    "horse": "Eukarya",
    "cow": "Eukarya",
    "sheep": "Eukarya",
    "goat": "Eukarya",
    "rabbit": "Eukarya",
    "deer": "Eukarya",
    "fox": "Eukarya",
    "bear": "Eukarya",
    "panda": "Eukarya",
    "elephant_seal": "Eukarya",
    "whale": "Eukarya",
    "dolphin": "Eukarya",
    "shark": "Eukarya",
    "octopus": "Eukarya",
    "sloth": "Eukarya",
    "pangolin": "Eukarya",
    "hippopotamus": "Eukarya",
    "rhinoceros": "Eukarya",
    "camel": "Eukarya",
    "polar_bear": "Eukarya",
    "cheetah": "Eukarya",
    "wolf": "Eukarya",
    "bat": "Eukarya",
    "pigeon": "Eukarya",
    "parrot": "Eukarya",
    "frog": "Eukarya",
    "turtle": "Eukarya",
    "crocodile": "Eukarya",
    "komodo_dragon": "Eukarya",
    "gorilla": "Eukarya",
    "chimpanzee": "Eukarya",
    "lemur": "Eukarya",
    "meerkat": "Eukarya",
    "peacock": "Eukarya",
    "ostrich": "Eukarya",
    "platypus": "Eukarya",
    "hedgehog": "Eukarya",
    "beaver": "Eukarya",
    "armadillo": "Eukarya",
    "raccoon": "Eukarya",
    "kookaburra": "Eukarya",
    "anteater": "Eukarya",
    "elephant_shrew": "Eukarya",
    "lemming": "Eukarya",
    "quokka": "Eukarya",
    "gazelle": "Eukarya",
    "toucan": "Eukarya",
    "spider": "Eukarya",
    "snail": "Eukarya",
    "jellyfish": "Eukarya",
    "crab": "Eukarya",
    "starfish": "Eukarya",
    "seahorse": "Eukarya",
    "butterfly": "Eukarya",
    "dragonfly": "Eukarya",
    "bee": "Eukarya",
    "mosquito": "Eukarya",
    "fly": "Eukarya",
    "ladybug": "Eukarya",
    "caterpillar": "Eukarya",
    "lizard": "Eukarya",
    "gecko": "Eukarya",
    "iguana": "Eukarya",
    "chameleon": "Eukarya",
    "tarantula": "Eukarya",
    "scorpion": "Eukarya",
    "millipede": "Eukarya",
    "centipede": "Eukarya",
    "slug": "Eukarya",
    "worm": "Eukarya",
    "fish": "Eukarya",
    "goldfish": "Eukarya",
    "clownfish": "Eukarya",
    "shrimp": "Eukarya",
    "lobster": "Eukarya",
    "coral": "Eukarya",
    "whale_shark": "Eukarya",
    "hammerhead_shark": "Eukarya",
    "ray": "Eukarya",
    "sea_turtle": "Eukarya",
    "seagull": "Eukarya",
    "pelican": "Eukarya",
    "albatross": "Eukarya",
    "emu": "Eukarya",
    "kiwi": "Eukarya",
    "puffin": "Eukarya",
    "otter": "Eukarya",
    "seal": "Eukarya"}

    def __init__(self):
        self.name = input("Enter your name: ")
        print(f'Hello {self.name}, Welcome to the Animal Classification Program')
        print('\n')
        self.option = input('Choose from the options below: \n1. Information about Domain. \n2. Information about Animal Kingdom. \n3. Information about Phylum. \n4. Information about Class. \n4. Information about Order. \n5. Information about Family \n6. Information about Genus. \n7. Information about Species. \n8. Information about species. \n9. Know the category of an animal \n')
        print('\n')
        if self.option == '1':
            self.s_domain(),print('\n'),self.Bacteria(),print('\n'),self.Archaea(),print('\n')
        elif self.option == '2':
            self.s_kingdom(),print('\n'),self.Animal(),print('\n'),self.Plants(),print('\n'),self.Fungi(),print('\n'),self.Eubacteria(),print('\n'),self.Archaebacteria(),print('\n')
        elif self.option == '3':
            self.s_phylum(),print('\n'),self.porifera(),print('\n'),self.cnidaria(),print('\n'),self.Platyhelminthes(),print('\n'),self.Nematoda(),print('\n'),self.Mollusca(),print('\n'),self.Annelida(),print('\n'),self.Arthropoda(),print('\n'),self.Echinodermata(),print('\n'),self.Chordata(),print('\n')
        elif self.option == '4':
            self.s_class(),print('\n'),self.Agnatha(),print('\n'),self.Chrondrichtyes(),print('\n'),self.Osteichthyes(),print('\n'),self.Amphibia(),print('\n'),self.Reptilia(),print('\n'),self.Aves(),print('\n'),self.Mammalia(),print('\n')
        elif self.option == '5':
            self.s_order(),print('\n'),self.Artiodactyla(),print('\n'),self.Carnivora(),print('\n'),self.Rodentia(),print('\n'),self.Chiropptera(),print('\n'),self.Cetacea(),print('\n'),self.Primates(),print('\n')
        elif self.option == '6':
            self.s_family(),print('\n'),self.vertibrates(),print('\n'),self.fish(),print('\n'),self.amphibians(),print('\n'),self.reptiles(),print('\n'),self.birds(),print('\n'),self.mammals(),print('\n'),self.invertibrates(),print('\n'),self.porifera(),print('\n'),self.cnidaria(),print('\n'),self.Platyhelminthes(),print('\n'),self.Nematoda(),print('\n'),self.Mollusca(),print('\n'),self.Annelida(),print('\n'),self.Arthropoda(),print('\n'),self.Echinodermata(),print(),self.Ctenophora(),print('\n'),self.Rotifera(),print('\n'),self.Tardigrada(),print('\n'),self.Hemichordata(),print('\n')
        elif self.option == '7':
            self.s_genus(),print('\n'),self.panthera(),print('\n'),self.canis(),print('\n'),self.felis(),print('\n'),self.elephas(),print('\n'),self.equus(),print('\n'),self.mus(),print('\n')
        elif self.option == '8':
            self.s_species(),print('\n')
        elif self.option == '9':
            #for i in animal_species:
                #print(i)
            self.a_name = input("Enter the animal name: ")
            print('\n')
            for i in self.animal_species:
                if i == self.a_name:
                    print(f'Species of {i} is: {self.animal_species[i]}')
            for i in self.animals_genus:
                if i == self.a_name:
                    print(f'Genus of {i} is: {self.animals_genus[i]}')
            for i in self.animal_families:
                if i == self.a_name:
                    print(f'Family of {i} is: {self.animal_families[i]}')
            for i in self.animal_orders:
                if i == self.a_name:
                    print(f'Order of {i} is: {self.animal_orders[i]}')
            for i in self.animal_classes:
                if i == self.a_name:
                    print(f'Class of {i} is: {self.animal_classes[i]}')
            for i in self.animal_phyla:
                if i == self.a_name:
                    print(f'Phylum of {i} is: {self.animal_phyla[i]}')
            for i in self.animal_kingdoms:
                if i == self.a_name:
                    print(f'Kingdom of {i} is: {self.animal_kingdoms[i]}')
            for i in self.animal_domains:
                if i == self.a_name:
                    print(f'Domain of {i} is: {self.animal_domains[i]}')

# %%
a = Animal_Classification()
# Out:
# Enter your name: r
# Hello r, Welcome to the Animal Classification Program
#
#
# Choose from the options below:
# 1. Information about Domain.
# 2. Information about Animal Kingdom.
# 3. Information about Phylum.
# 4. Information about Class.
# 4. Information about Order.
# 5. Information about Family
# 6. Information about Genus.
# 7. Information about Species.
# 8. Information about species.
# 9. Know the category of an animal
# 9
#
#
# Enter the animal name: dog
#
#
# Species of dog is: Canis lupus familiaris
# Genus of dog is: Canis
# Family of dog is: Mammal
# Order of dog is: Carnivora
# Class of dog is: Mammalia
# Phylum of dog is: Chordata
# Kingdom of dog is: Animalia
# Domain of dog is: Eukarya
